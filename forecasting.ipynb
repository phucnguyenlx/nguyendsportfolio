# %% [markdown]
# <a href="https://colab.research.google.com/github/phucnguyenlx/nguyendsportfolio/blob/main/forecasting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import os

drive.mount('/content/drive') # must mount the drive first then set current directory
os.chdir('/content/drive/MyDrive/1. Practice') # set the current directory
# !pwd  # now it will show your Practice folder

#Now if DAvid wants to run must always do subfolder/file.txt etc. relative or absolute path to the file
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/1. Practice

# %%
#Defitinion: notebooks/
# Contains: forecasting.ipynb
# Purpose: Show your analysis, predictions, and visualizations.
# Tip: Make it clean, annotated, and readable. Use Markdown to explain steps.
#3

# %%
# !pip install -r requirements.txt

#Hint:
#pip install <package>      # single package
#pip install -r <file>      # read list of packages from file
# Out:
# ...
#   Using cached pandas-2.1.0.tar.gz (4.3 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   error: subprocess-exited-with-error
#
#   × Preparing metadata (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (pyproject.toml) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
#!python src/download_data.py

# %%
# !pwd
# Out:
# /content/drive/MyDrive/1. Practice

# %%
import sys
import os

# Get the project root folder
PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), ".."))  # one folder up from notebooks/
sys.path.append(PROJECT_ROOT)

# Now imports work
from src.preprocess import preprocess_data
df = preprocess_data()
df.head()
# Out:
# ok
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_844/1051369820.py in <cell line: 0>()
#       8 # Now imports work
#       9 from src.preprocess import preprocess_data
# ---> 10 df = preprocess_data()
#      11 df.head()
#
# /content/drive/MyDrive/1. Practice/src/preprocess.py in preprocess_data(input_file, output_file)
#      12
#      13     # Load data
# ---> 14     df = pd.read_csv(input_file, parse_dates=['Date'])
#      15     df.sort_values('Date', inplace=True)
#      16
#
# ...
